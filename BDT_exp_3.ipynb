# %%
# ==============================
# STEP 1: Install Java & Hadoop
# ==============================
# !apt-get update -y
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download Hadoop 3.3.6
# !wget -q https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /usr/local/hadoop

# ==============================
# STEP 2: Setup Hadoop Env
# ==============================
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop"
os.environ["PATH"] = f"{os.environ['HADOOP_HOME']}/bin:{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]

# !hadoop version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [346 B]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,807 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,274 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,305 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,796 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,363 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,577 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,584 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,687 kB]
# Fetched 33.8 MB in 6s (5,824 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# ==============================
# STEP 3: Prepare Input Files
# ==============================
# !mkdir input_data

with open("input_data/input1.txt", "w") as f:
    f.write("Hello World Bye World\n")

with open("input_data/input2.txt", "w") as f:
    f.write("Hello Hadoop Goodbye Hadoop\n")

# !cat input_data/*
# Out:
# Hello World Bye World
# Hello Hadoop Goodbye Hadoop

# %%
# %%bash
# cat > mapper.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# for line in sys.stdin:
#     line = line.strip()
#     for word in line.split():
#         print(f"{word}\t1")
# EOF
#
# cat > combiner.py <<'EOF'
# #!/usr/bin/env python3
# import sys
# from collections import defaultdict
#
# counts = defaultdict(int)
# for line in sys.stdin:
#     word, count = line.strip().split("\t")
#     counts[word] += int(count)
#
# for word, count in counts.items():
#     print(f"{word}\t{count}")
# EOF
#
# cat > reducer.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# current_word = None
# current_count = 0
#
# for line in sys.stdin:
#     word, count = line.strip().split("\t")
#     count = int(count)
#
#     if current_word == word:
#         current_count += count
#     else:
#         if current_word:
#             print(f"{current_word}\t{current_count}")
#         current_word = word
#         current_count = count
#
# if current_word:
#     print(f"{current_word}\t{current_count}")
# EOF
#
# chmod +x mapper.py combiner.py reducer.py

# %%
# ==============================
# STEP 5: Run Hadoop Streaming Job
# ==============================
# !hadoop fs -rm -r -f input output

# Put input files into HDFS
# !hadoop fs -mkdir -p input
# !hadoop fs -put input_data/* input/

# Run Hadoop Streaming
# !hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-*.jar \
  -input input \
  -output output \
  -mapper mapper.py \
  -combiner combiner.py \
  -reducer reducer.py \
  -file mapper.py \
  -file combiner.py \
  -file reducer.py
# Out:
# 2025-09-25 04:37:26,098 INFO Configuration.deprecation: io.bytes.per.checksum is deprecated. Instead, use dfs.bytes-per-checksum
# Deleted input
# Deleted output
# 2025-09-25 04:37:30,587 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py, combiner.py, reducer.py] [] /tmp/streamjob7637688276975276996.jar tmpDir=null
# 2025-09-25 04:37:31,100 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-09-25 04:37:31,192 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-09-25 04:37:31,192 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-09-25 04:37:31,210 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-09-25 04:37:31,392 INFO mapred.FileInputFormat: Total input files to process : 2
# 2025-09-25 04:37:31,410 INFO mapreduce.JobSubmitter: number of splits:2
# 2025-09-25 04:37:31,546 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1458905970_0001
# 2025-09-25 04:37:31,546 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2025-09-25 04:37:31,850 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper.py as file:/tmp/hadoop-root/mapred/local/job_local1458905970_0001_99046ddc-cf42-412d-afb0-6ab6c7670073/mapper.py
# 2025-09-25 04:37:31,884 INFO mapred.LocalDistributedCacheManager: Localized file:/content/combiner.py as file:/tmp/hadoop-root/mapred/local/job_local1458905970_0001_06d9c853-4155-4918-a894-945e9659cdaf/combiner.py
# 2025-09-25 04:37:31,885 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer.py as file:/tmp/hadoop-root/mapred/local/job_local1458905970_0001_40c4cc97-0b54-4809-9004-ed733bef127a/reducer.py
# 2025-09-25 04:37:32,034 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-09-25 04:37:32,036 INFO mapreduce.Job: Running job: job_local1458905970_0001
# 2025-09-25 04:37:32,037 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-09-25 04:37:32,109 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2025-09-25 04:37:32,117 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-09-25 04:37:32,117 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-09-25 04:37:32,154 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2025-09-25 04:37:32,157 INFO mapred.LocalJobRunner: Starting task: attempt_local1458905970_0001_m_000000_0
# 2025-09-25 04:37:32,182 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-09-25 04:37:32,182 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-09-25 04:37:32,207 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-09-25 04:37:32,219 INFO mapred.MapTask: Processing split: file:/content/input/input2.txt:0+28
# 2025-09-25 04:37:32,232 INFO mapred.MapTask: numReduceTasks: 1
# 2025-09-25 04:37:32,290 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-09-25 04:37:32,290 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-09-25 04:37:32,290 INFO mapred.MapTask: soft limit at 83886080
# 2025-09-25 04:37:32,290 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-09-25 04:37:32,290 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-09-25 04:37:32,294 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-09-25 04:37:32,299 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-09-25 04:37:32,303 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2025-09-25 04:37:32,304 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2025-09-25 04:37:32,304 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2025-09-25 04:37:32,304 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2025-09-25 04:37:32,305 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2025-09-25 04:37:32,305 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2025-09-25 04:37:32,306 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2025-09-25 04:37:32,307 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2025-09-25 04:37:32,307 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2025-09-25 04:37:32,307 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2025-09-25 04:37:32,308 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-09-25 04:37:32,308 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-09-25 04:37:32,331 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-09-25 04:37:32,383 INFO streaming.PipeMapRed: Records R/W=1/1
# 2025-09-25 04:37:32,389 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-09-25 04:37:32,390 INFO streaming.PipeMapRed: mapRedFinished
# 2025-09-25 04:37:32,392 INFO mapred.LocalJobRunner:
# 2025-09-25 04:37:32,392 INFO mapred.MapTask: Starting flush of map output
# 2025-09-25 04:37:32,392 INFO mapred.MapTask: Spilling map output
# 2025-09-25 04:37:32,392 INFO mapred.MapTask: bufstart = 0; bufend = 36; bufvoid = 104857600
# 2025-09-25 04:37:32,392 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214384(104857536); length = 13/6553600
# 2025-09-25 04:37:32,403 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-09-25 04:37:32,405 INFO Configuration.deprecation: mapred.skip.map.auto.incr.proc.count is deprecated. Instead, use mapreduce.map.skip.proc-count.auto-incr
# 2025-09-25 04:37:32,418 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-09-25 04:37:32,465 INFO streaming.PipeMapRed: Records R/W=4/1
# 2025-09-25 04:37:32,472 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-09-25 04:37:32,472 INFO streaming.PipeMapRed: mapRedFinished
# 2025-09-25 04:37:32,472 INFO mapred.MapTask: Finished spill 0
# 2025-09-25 04:37:32,484 INFO mapred.Task: Task:attempt_local1458905970_0001_m_000000_0 is done. And is in the process of committing
# 2025-09-25 04:37:32,485 INFO mapred.LocalJobRunner: Records R/W=4/1
# 2025-09-25 04:37:32,486 INFO mapred.Task: Task 'attempt_local1458905970_0001_m_000000_0' done.
# 2025-09-25 04:37:32,494 INFO mapred.Task: Final Counters for attempt_local1458905970_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=1940
# 		FILE: Number of bytes written=646217
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=4
# 		Map output bytes=36
# 		Map output materialized bytes=39
# 		Input split bytes=82
# 		Combine input records=4
# 		Combine output records=3
# 		Spilled Records=3
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=310378496
# 	File Input Format Counters
# 		Bytes Read=44
# 2025-09-25 04:37:32,495 INFO mapred.LocalJobRunner: Finishing task: attempt_local1458905970_0001_m_000000_0
# 2025-09-25 04:37:32,495 INFO mapred.LocalJobRunner: Starting task: attempt_local1458905970_0001_m_000001_0
# 2025-09-25 04:37:32,497 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-09-25 04:37:32,497 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-09-25 04:37:32,497 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-09-25 04:37:32,500 INFO mapred.MapTask: Processing split: file:/content/input/input1.txt:0+22
# 2025-09-25 04:37:32,503 INFO mapred.MapTask: numReduceTasks: 1
# 2025-09-25 04:37:32,556 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-09-25 04:37:32,556 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-09-25 04:37:32,556 INFO mapred.MapTask: soft limit at 83886080
# 2025-09-25 04:37:32,556 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-09-25 04:37:32,556 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-09-25 04:37:32,557 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-09-25 04:37:32,560 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-09-25 04:37:32,577 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-09-25 04:37:32,647 INFO streaming.PipeMapRed: Records R/W=1/1
# 2025-09-25 04:37:32,658 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-09-25 04:37:32,659 INFO streaming.PipeMapRed: mapRedFinished
# 2025-09-25 04:37:32,659 INFO mapred.LocalJobRunner:
# 2025-09-25 04:37:32,659 INFO mapred.MapTask: Starting flush of map output
# 2025-09-25 04:37:32,659 INFO mapred.MapTask: Spilling map output
# 2025-09-25 04:37:32,659 INFO mapred.MapTask: bufstart = 0; bufend = 30; bufvoid = 104857600
# 2025-09-25 04:37:32,659 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214384(104857536); length = 13/6553600
# 2025-09-25 04:37:32,666 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-09-25 04:37:32,679 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-09-25 04:37:32,734 INFO streaming.PipeMapRed: Records R/W=4/1
# 2025-09-25 04:37:32,742 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-09-25 04:37:32,742 INFO streaming.PipeMapRed: mapRedFinished
# 2025-09-25 04:37:32,743 INFO mapred.MapTask: Finished spill 0
# 2025-09-25 04:37:32,746 INFO mapred.Task: Task:attempt_local1458905970_0001_m_000001_0 is done. And is in the process of committing
# 2025-09-25 04:37:32,747 INFO mapred.LocalJobRunner: Records R/W=4/1
# 2025-09-25 04:37:32,747 INFO mapred.Task: Task 'attempt_local1458905970_0001_m_000001_0' done.
# 2025-09-25 04:37:32,747 INFO mapred.Task: Final Counters for attempt_local1458905970_0001_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2161
# 		FILE: Number of bytes written=646283
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=4
# 		Map output bytes=30
# 		Map output materialized bytes=34
# 		Input split bytes=82
# 		Combine input records=4
# 		Combine output records=3
# 		Spilled Records=3
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=415760384
# 	File Input Format Counters
# 		Bytes Read=38
# 2025-09-25 04:37:32,748 INFO mapred.LocalJobRunner: Finishing task: attempt_local1458905970_0001_m_000001_0
# 2025-09-25 04:37:32,748 INFO mapred.LocalJobRunner: map task executor complete.
# 2025-09-25 04:37:32,751 INFO mapred.LocalJobRunner: Starting task: attempt_local1458905970_0001_r_000000_0
# 2025-09-25 04:37:32,751 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-09-25 04:37:32,758 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-09-25 04:37:32,758 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-09-25 04:37:32,758 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-09-25 04:37:32,761 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@7061c2c4
# 2025-09-25 04:37:32,763 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-09-25 04:37:32,780 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2116865152, maxSingleShuffleLimit=529216288, mergeThreshold=1397131008, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-09-25 04:37:32,783 INFO reduce.EventFetcher: attempt_local1458905970_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-09-25 04:37:32,813 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1458905970_0001_m_000001_0 decomp: 30 len: 34 to MEMORY
# 2025-09-25 04:37:32,816 INFO reduce.InMemoryMapOutput: Read 30 bytes from map-output for attempt_local1458905970_0001_m_000001_0
# 2025-09-25 04:37:32,818 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 30, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->30
# 2025-09-25 04:37:32,820 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1458905970_0001_m_000000_0 decomp: 35 len: 39 to MEMORY
# 2025-09-25 04:37:32,821 INFO reduce.InMemoryMapOutput: Read 35 bytes from map-output for attempt_local1458905970_0001_m_000000_0
# 2025-09-25 04:37:32,821 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 35, inMemoryMapOutputs.size() -> 2, commitMemory -> 30, usedMemory ->65
# 2025-09-25 04:37:32,822 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-09-25 04:37:32,822 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-09-25 04:37:32,822 INFO reduce.MergeManagerImpl: finalMerge called with 2 in-memory map-outputs and 0 on-disk map-outputs
# 2025-09-25 04:37:32,827 INFO mapred.Merger: Merging 2 sorted segments
# 2025-09-25 04:37:32,827 INFO mapred.Merger: Down to the last merge-pass, with 2 segments left of total size: 49 bytes
# 2025-09-25 04:37:32,828 INFO reduce.MergeManagerImpl: Merged 2 segments, 65 bytes to disk to satisfy reduce memory limit
# 2025-09-25 04:37:32,828 INFO reduce.MergeManagerImpl: Merging 1 files, 67 bytes from disk
# 2025-09-25 04:37:32,829 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-09-25 04:37:32,829 INFO mapred.Merger: Merging 1 sorted segments
# 2025-09-25 04:37:32,830 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 57 bytes
# 2025-09-25 04:37:32,830 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-09-25 04:37:32,833 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer.py]
# 2025-09-25 04:37:32,835 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-09-25 04:37:32,837 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2025-09-25 04:37:32,852 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-09-25 04:37:32,909 INFO streaming.PipeMapRed: Records R/W=6/1
# 2025-09-25 04:37:32,916 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-09-25 04:37:32,916 INFO streaming.PipeMapRed: mapRedFinished
# 2025-09-25 04:37:32,917 INFO mapred.Task: Task:attempt_local1458905970_0001_r_000000_0 is done. And is in the process of committing
# 2025-09-25 04:37:32,918 INFO mapred.LocalJobRunner: 2 / 2 copied.
# 2025-09-25 04:37:32,918 INFO mapred.Task: Task attempt_local1458905970_0001_r_000000_0 is allowed to commit now
# 2025-09-25 04:37:32,919 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1458905970_0001_r_000000_0' to file:/content/output
# 2025-09-25 04:37:32,920 INFO mapred.LocalJobRunner: Records R/W=6/1 > reduce
# 2025-09-25 04:37:32,920 INFO mapred.Task: Task 'attempt_local1458905970_0001_r_000000_0' done.
# 2025-09-25 04:37:32,921 INFO mapred.Task: Final Counters for attempt_local1458905970_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2365
# 		FILE: Number of bytes written=646403
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=73
# 		Reduce input records=6
# 		Reduce output records=5
# 		Spilled Records=6
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=415760384
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=53
# 2025-09-25 04:37:32,921 INFO mapred.LocalJobRunner: Finishing task: attempt_local1458905970_0001_r_000000_0
# 2025-09-25 04:37:32,921 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2025-09-25 04:37:33,115 INFO mapreduce.Job: Job job_local1458905970_0001 running in uber mode : false
# 2025-09-25 04:37:33,115 INFO mapreduce.Job:  map 100% reduce 100%
# 2025-09-25 04:37:33,116 INFO mapreduce.Job: Job job_local1458905970_0001 completed successfully
# 2025-09-25 04:37:33,123 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=6466
# 		FILE: Number of bytes written=1938903
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=2
# 		Map output records=8
# 		Map output bytes=66
# 		Map output materialized bytes=73
# 		Input split bytes=164
# 		Combine input records=8
# 		Combine output records=6
# 		Reduce input groups=5
# 		Reduce shuffle bytes=73
# 		Reduce input records=6
# 		Reduce output records=5
# 		Spilled Records=12
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=1141899264
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=82
# 	File Output Format Counters
# 		Bytes Written=53
# 2025-09-25 04:37:33,123 INFO streaming.StreamJob: Output directory: output

# %%
# ==============================
# STEP 6: Check Output
# ==============================
# !hadoop fs -cat output/part-00000
# Out:
# Bye	1
# Goodbye	1
# Hadoop	2
# Hello	2
# World	2
